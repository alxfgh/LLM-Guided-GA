# %%
import csv
import json

# Define the input and output file paths
csv_file_path = "PubChem10M_SELFIES.csv"
json_file_path = "output.json"

# Initialize an empty list to store the data
data = []

# Read the CSV file
with open(csv_file_path, "r") as csv_file:
    reader = csv.reader(csv_file)
    
    # Skip the header row
    next(reader)
    
    # Process each row
    for row in reader:
        line_content = row[0].strip()
        
        # Create a dictionary with the required format
        row_data = {
            "instruction": "Generate a valid molecule:",
            "output": line_content
        }
        
        # Add the row data to the list
        data.append(row_data)

# Save the data as a JSON file
with open(json_file_path, "w") as json_file:
    json.dump(data, json_file)

# %%
# !git clone https://github.com/Lightning-AI/lit-llama
! pip install lit-llama/ -r lit-llama/requirements.txt
# Out:
# Cloning into 'lit-llama'...
# Processing c:\users\alexg\coding projects\llm-guided-ga\lit-llama
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Cloning https://github.com/Lightning-AI/lightning (to revision master) to c:\users\alexg\appdata\local\temp\pip-install-08lnoaw0\lightning_8cc4f7c9fd4240a18c2330c7013d833d
#   Resolved https://github.com/Lightning-AI/lightning to commit a36af3f9f855a4735fdc97c5e08bebb8a7467bf3
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
# ...

# %%
# !pip install datasets

# %%
import pandas as pd; from datasets import load_dataset; load_dataset("zpn/pubchem_selfies")['train']['CAN_SELFIES'].to_pandas().to_csv('dataset.csv', index=False)
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import pandas as pd; from datasets import load_dataset; load_dataset("zpn/pubchem_selfies")['train']['CAN_SELFIES'].to_pandas().to_csv('dataset.csv', index=False)
#
# File c:\Users\alexg\Coding Projects\LLM-Guided-GA\.venv\Lib\site-packages\datasets\load.py:1797, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    1794 try_from_hf_gcs = path not in _PACKAGED_DATASETS_MODULES
#    1796 # Download and prepare data
# -> 1797 builder_instance.download_and_prepare(
#    1798     download_config=download_config,
#    1799     download_mode=download_mode,
# ...

# %%
import copy

import group_selfies as sf
from rdkit.Chem import AllChem as Chem
import rdkit.Chem.Draw as Draw
import numpy as np
import random 
import copy
from tqdm import tqdm
import time
import numpy as np
from group_selfies import GroupGrammar


global grammar
grammar = GroupGrammar.essential_set()

# %%
import csv
i = 0
# open the input and output files
with open('output_5.csv', 'r') as input_file, open('outputSelfie_5.csv', 'w', newline='', encoding='utf-8') as output_file:
    # Skip the header line in the input file
    next(input_file)
    # create a CSV writer object
    writer = csv.writer(output_file)

    # loop over each line in the input file
    for line in input_file:
        i = i + 1
        if i % 10000 == 0:
            print(i)
        try:
            # process the line using the process_line() function
            values = grammar.full_encoder(Chem.MolFromSmiles(line.strip()))
            # write the values to the output file
            writer.writerow([values])
        except:
            # if an error occurs, just skip the line
            print(f"Error in line: {line}")
            continue
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# ...
